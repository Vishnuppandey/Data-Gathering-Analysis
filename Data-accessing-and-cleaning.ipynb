# %%
import pandas as pd
import numpy as np
import re

# %%
patients=pd.read_csv('patients.csv')
treatment=pd.read_csv('treatments.csv')
adverse=pd.read_csv('adverse_reactions.csv')
treatment_cut=pd.read_csv('treatments_cut.csv')

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %%
treatment
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0             NaN
# 1            0.97
# ...

# %%
treatment_cut
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0       jožka   resanovič  22u - 30u          -         7.56       7.22
# 1   inunnguaq    heilmann  57u - 67u          -         7.85       7.45
# 2       alwin    svensson  36u - 39u          -         7.78       7.34
# 3         thể       lương          -  61u - 64u         7.64       7.22
# 4      amanda     ribeiro  36u - 44u          -         7.85       7.47
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0           0.34
# 1            NaN
# 2            NaN
# 3           0.92
# ...

# %%
adverse
# Out:
#      given_name     surname           adverse_reaction
# 0         berta  napolitani  injection site discomfort
# 1          lena        baer               hypoglycemia
# 2        joseph         day               hypoglycemia
# 3        flavia  fiorentino                      cough
# 4       manouck     wubbels          throat irritation
# 5       jasmine       sykes               hypoglycemia
# 6        louise     johnson               hypoglycemia
# 7       albinca     komavec               hypoglycemia
# 8           noe      aranda               hypoglycemia
# 9         sofia   hermansen  injection site discomfort
# 10        tegan     johnson                   headache
# 11         abel     yonatan                      cough
# 12    abdul-nur         isa               hypoglycemia
# 13         leon      scholz  injection site discomfort
# 14     gabriele     saenger               hypoglycemia
# 15       jia li        teng                     nausea
# ...

# %%
with pd.ExcelWriter('clinical_trials1.xlsx') as writer:
    patients.to_excel(writer,sheet_name='patients')
    treatment.to_excel(writer,sheet_name='treatments')
    treatment_cut.to_excel(writer,sheet_name='treatment_cut')
    adverse.to_excel(writer,sheet_name='adverse_reaction')

# %% [raw]
# # Issues with dataset
#
# 1-Dirty Data
#
# Table - 'Patient'
#
# - Patient id 9 has name 'davisd' instead of 'david'- Accuracy
# - State has some full name and some short name - Consistency
# - Zip_code has different no of digit it should be 5 digit - VALIDITY
# - 12 missing values in address,city,state,zip_code,country,contact - cOMPLETNESS
# - incorrect data types for sex,zip_code,birthdate - VALIDITY
# - duplicate entry with the name of john doe - Accuracy
# - one patient has weight=48 pounds - ACCURACY
# - one patient has height=27 inches - ACCURACY
#
# Table - 'Treatments' & 'treatments_cut'
#
# - given_name and surname first letter should be capitalize - CONSISTENCY
#
# - unit associated with aurlin and novodra should be removed - VALIDITY
#
# -  in aurlin and novodra should be treated as nan - Validity
#
# - missing values in hbac1_change - 'Completion'
#
# - Joseph deo has duplicate entry - 'Accuracy'
#
# - in hba1c_change 9 has been inserted instead of 4 - 'Accuracy'
#
# Table - 'adverse_reaction'
#
# - given_name and sirname are all in lower case - 'Consistency'
#
#
#
# 2-Messy Data
#
# Table - 'Patient' & 'treatments_cut'
#
# -Contact columns should be divided into two columns and that columns could be phone no and email
#
# Table - 'Treatments'
#
# - aurlin should be divided into columns with columns name as start and end
#
#
# Table - 'adverse_reaction'
#
# - the table should not exist indipendently

# %% [raw]
#  Automatic Assesssment
#
# -head and tail
# -sample
# -info
# -isnull
# -duplicated
# -describe

# %%
patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
patients[patients['address'].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
patients.duplicated().sum()
# Out:
# 0

# %%
patients['patient_id'].duplicated().sum()
# Out:
# 0

# %%
patients[patients.duplicated(subset=['given_name','surname'])]
# Out:
#      patient_id assigned_sex given_name surname          address      city  \
# 229         230         male       John     Doe  123 Main Street  New York
# 237         238         male       John     Doe  123 Main Street  New York
# 244         245         male       John     Doe  123 Main Street  New York
# 251         252         male       John     Doe  123 Main Street  New York
# 277         278         male       John     Doe  123 Main Street  New York
#
#     state  zip_code        country                      contact birthdate  \
# 229    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 237    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 244    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 251    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 277    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
#
#      weight  height   bmi
# 229   180.0      72  24.4
# ...

# %%
treatment[treatment.duplicated()]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatment[treatment.duplicated(subset=['given_name','surname'])]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatment_cut[treatment_cut.duplicated()]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []

# %%
adverse[adverse.duplicated()]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, adverse_reaction]
# Index: []

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
treatment.sort_values('hba1c_start')
# Out:
#     given_name      surname    auralin    novodra  hba1c_start  hba1c_end  \
# 270       mika   martinsson  34u - 43u          -         7.50       7.17
# 113       kari  laatikainen  39u - 43u          -         7.50       7.11
# 126     jowita   wiśniewska          -  22u - 23u         7.50       7.08
# 53      nasser      mansour          -  33u - 31u         7.51       7.06
# 105     finlay     sheppard          -  31u - 30u         7.51       7.17
# ..         ...          ...        ...        ...          ...        ...
# 25      benoît       bonami          -  44u - 43u         9.82       9.40
# 171    justyna    kowalczyk  24u - 34u          -         9.84       9.44
# 81      robert       wagner  43u - 49u          -         9.84       9.52
# 75   mackenzie        mckay          -  44u - 43u         9.87       9.48
# 166      annie        allen  36u - 42u          -         9.95       9.58
#
#      hba1c_change
# 270          0.33
# 113           NaN
# 126          0.92
# ...

# %%
treatment.sort_values('hba1c_end')
# Out:
#     given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 39   krisztina     magyar          -  32u - 27u         7.52       7.01
# 80      hideki  haraguchi          -  37u - 35u         7.59       7.05
# 187       león    reynoso          -  38u - 40u         7.59       7.06
# 53      nasser    mansour          -  33u - 31u         7.51       7.06
# 86     ananías   enríquez          -  44u - 45u         7.58       7.07
# ..         ...        ...        ...        ...          ...        ...
# 192      valur  bjarkason          -  31u - 36u         9.71       9.41
# 171    justyna  kowalczyk  24u - 34u          -         9.84       9.44
# 75   mackenzie      mckay          -  44u - 43u         9.87       9.48
# 81      robert     wagner  43u - 49u          -         9.84       9.52
# 166      annie      allen  36u - 42u          -         9.95       9.58
#
#      hba1c_change
# 39           0.51
# 80           0.54
# 187          0.53
# 53           0.95
# ...

# %%
treatment.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
treatment.sort_values('hba1c_change',na_position='first')
# Out:
#     given_name      surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika     jindrová  41u - 48u          -         7.63       7.20
# 2     yukitaka     takenaka          -  39u - 36u         7.68       7.25
# 8        saber       ménard          -  54u - 54u         8.08       7.70
# 9         asia      woźniak  30u - 36u          -         7.76       7.37
# 10      joseph          day  29u - 36u          -         7.70       7.19
# ..         ...          ...        ...        ...          ...        ...
# 49     jackson      addison          -  42u - 42u         7.99       7.51
# 17        gina         cain          -  36u - 36u         7.88       7.40
# 32       laura  ehrlichmann          -  43u - 40u         7.95       7.46
# 245         wu         sung          -  47u - 48u         7.61       7.12
# 138    giovana        rocha          -  23u - 21u         7.87       7.38
#
#      hba1c_change
# 0             NaN
# 2             NaN
# 8             NaN
# ...

# %% [markdown]
# Note - Assessing Data is an Iterative Process

# %% [raw]
# Data Quality Dimensions
#
# 1.Completeness -> is Data missing?
# 2.Accuracy -> Data is valid but not accurate -> weight of person -> 1kg
# 3.Validity -> is data invalid -> negative height -> duplicate patient id
# 4.Consistency -> both valid and accurate but wrriten differently -> New Youk and NY
#
# Order of severity
# Completness <- Validity <- Accuracy <- Consistency
#
# Data Cleaning Order
# 1

# %%
patient_df=patients.copy()
treatment_df=treatment.copy()
treatment_cut_df=treatment_cut.copy()
adverse_df=adverse.copy()

# %%
patient_df.fillna('no data',inplace=True)

# %%
patient_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       503 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      503 non-null    object
#  8   country       503 non-null    object
#  9   contact       503 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 55.1+ KB

# %%
treatment_df.fillna('no data',inplace=True)

# %%
treatment_df
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#     hba1c_change
# 0        no data
# 1           0.97
# ...

# %%
patients
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state  zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California   92390.0
# 1    2370 University Hill Road          Armstrong    Illinois   61812.0
# 2        1493 Poling Farm Road               York    Nebraska   68467.0
# ...

# %%
treatment_df
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#     hba1c_change
# 0        no data
# 1           0.97
# ...

# %%
treatment_df['hba1c_change']=treatment_df['hba1c_start']-treatment_df['hba1c_end']
treatment_cut_df['hba1c_change']=treatment_cut_df['hba1c_start']-treatment_cut_df['hba1c_end']

# %%
treatment_df
# Out:
#     given_name       surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika      jindrová  41u - 48u          -         7.63       7.20
# 1       elliot    richardson          -  40u - 45u         7.56       7.09
# 2     yukitaka      takenaka          -  39u - 36u         7.68       7.25
# 3         skye    gormanston  33u - 36u          -         7.97       7.62
# 4       alissa        montez          -  33u - 29u         7.78       7.46
# ..         ...           ...        ...        ...          ...        ...
# 275     albina      zetticci  45u - 51u          -         7.93       7.73
# 276       john   teichelmann          -  49u - 49u         7.90       7.58
# 277     mathea       lillebø  23u - 36u          -         9.04       8.67
# 278     vallie        prince  31u - 38u          -         7.64       7.28
# 279     samúel  guðbrandsson  53u - 56u          -         8.00       7.64
#
#      hba1c_change
# 0            0.43
# 1            0.47
# ...

# %%
treatment_cut_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    70 non-null     object
#  1   surname       70 non-null     object
#  2   auralin       70 non-null     object
#  3   novodra       70 non-null     object
#  4   hba1c_start   70 non-null     float64
#  5   hba1c_end     70 non-null     float64
#  6   hba1c_change  70 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 4.0+ KB

# %%
patients['contact'].head(20)
# Out:
# 0              951-719-9170ZoeWellish@superrito.com
# 1             PamelaSHill@cuvox.de+1 (217) 569-3204
# 2                  402-363-6804JaeMDebord@gustr.com
# 3        PhanBaLiem@jourrapide.com+1 (732) 636-8246
# 4                   334-515-7487TimNeudorf@cuvox.de
# 5          386-334-5237RafaelCardosoCosta@gustr.com
# 6                 775-533-5933MaryBAdams@einrot.com
# 7              XiuxiuChang@einrot.com1 408 778 3236
# 8           816-265-9578DavidGustafsson@armyspy.com
# 9     SophieCabreraIbarra@teleworm.us1 718 795 9124
# 10           906-478-8949SandyGunnarsson@dayrep.com
# 11       Abdul-NurMummarIsa@rhyta.com1 931 207 0839
# 12        OmeokachieIbeamaka@einrot.com434-509-2614
# 13       AnenechiChidi@armyspy.com+1 (205) 417-8095
# 14                AsiaWozniak@rhyta.com918-712-3469
# 15                  276-225-1955SrenFLund@gustr.com
# 16           LieuThiThuTam@dayrep.com1 559 765 7836
# 17         RoxanneAndreyeva@armyspy.com678-829-8578
# ...

# %%
def find_contact_details(text: str) -> tuple:
    # it the value is NaN, then return it
    if pd.isna(text):
        return np.nan
    
    # create the phone number pattern
    phone_number_pattern = re.compile(r"(\+[\d]{1,3}\s)?(\(?[\d]{3}\)?\s?-?[\d]{3}\s?-?[\d]{4})")
    # find the phone number from the value/text, as a result we will get a list
    phone_number  = re.findall(phone_number_pattern, text)

    # if length is 0, then the regex can't find any ph number, then define with NaN
    if len(phone_number) <= 0:
        phone_number = np.nan
    # if the country code is attached with the ph number, for that case, the first
    # element will be the country code and the 2nd element will be the actual ph
    # number. So, get that ph number
    elif len(phone_number) >= 2:
        phone_number = phone_number[1]
    # else, we will get the ph number. Grab it.
    else:
        phone_number = phone_number[0]

    # if we found the ph number (with/without country code), then remove that part from the actual value.
    # after removing the ph number, the remaining string might be the email address.
    possible_email_add = re.sub(phone_number_pattern, "", text).strip()

    # then return the ph number and the email address
    return phone_number, possible_email_add

# %%
patient_df['Phone']=patient_df['contact'].apply(lambda x:find_contact_details(x)).apply(lambda x:x[0])
patient_df['Email']=patient_df['contact'].apply(lambda x:find_contact_details(x)).apply(lambda x:x[1])

# %%
patient_df
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California  92390.0
# 1    2370 University Hill Road          Armstrong    Illinois  61812.0
# 2        1493 Poling Farm Road               York    Nebraska  68467.0
# ...

# %%
patient_df.drop(columns=['Contact','Email','Phone'],inplace=True)

# %%
patient_df
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California  92390.0
# 1    2370 University Hill Road          Armstrong    Illinois  61812.0
# 2        1493 Poling Farm Road               York    Nebraska  68467.0
# ...

# %%
treatments_df=pd.concat([treatment,treatment_cut])

# %%
treatments_df
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0    veronika    jindrová  41u - 48u          -         7.63       7.20
# 1      elliot  richardson          -  40u - 45u         7.56       7.09
# 2    yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3        skye  gormanston  33u - 36u          -         7.97       7.62
# 4      alissa      montez          -  33u - 29u         7.78       7.46
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0            NaN
# 1           0.97
# 2            NaN
# 3           0.35
# ...

# %%
treatments_df=treatments_df.melt(id_vars=['given_name','surname','hba1c_start','hba1c_end','hba1c_change'],var_name='type',value_name='dosage_range')
treatments_df
# Out:
#     given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0     veronika    jindrová         7.63       7.20           NaN  auralin
# 1       elliot  richardson         7.56       7.09          0.97  auralin
# 2     yukitaka    takenaka         7.68       7.25           NaN  auralin
# 3         skye  gormanston         7.97       7.62          0.35  auralin
# 4       alissa      montez         7.78       7.46          0.32  auralin
# ..         ...         ...          ...        ...           ...      ...
# 695     rovzan     kishiev         7.75       7.41          0.34  novodra
# 696      jakob    jakobsen         7.96       7.51          0.95  novodra
# 697      bernd   schneider         7.74       7.44          0.30  novodra
# 698      berta  napolitani         7.68       7.21           NaN  novodra
# 699     armina       sauvé         7.86       7.40           NaN  novodra
#
#     dosage_range
# 0      41u - 48u
# 1              -
# 2              -
# ...

# %%
treatments_df=treatments_df[treatments_df['dosage_range']!='-']

# %%
treatments_df
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20           NaN  auralin
# 3           skye  gormanston         7.97       7.62          0.35  auralin
# 6         sophia      haugen         7.65       7.27          0.38  auralin
# 7          eddie      archer         7.89       7.55          0.34  auralin
# 9           asia     woźniak         7.76       7.37           NaN  auralin
# ..           ...         ...          ...        ...           ...      ...
# 688  christopher    woodward         7.51       7.06          0.95  novodra
# 690        maret    sultygov         7.67       7.30           NaN  novodra
# 694        lixue       hsueh         9.21       8.80          0.91  novodra
# 696        jakob    jakobsen         7.96       7.51          0.95  novodra
# 698        berta  napolitani         7.68       7.21           NaN  novodra
#
#     dosage_range
# 0      41u - 48u
# 3      33u - 36u
# ...

# %%
treatments_df['dosage_start']=treatments_df['dosage_range'].str.split('-').str.get(0)
treatments_df['dosage_end']=treatments_df['dosage_range'].str.split('-').str.get(1)
# Out:
# C:\Users\pande\AppData\Local\Temp\ipykernel_14300\3603672503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatments_df['dosage_start']=treatments_df['dosage_range'].str.split('-').str.get(0)
# C:\Users\pande\AppData\Local\Temp\ipykernel_14300\3603672503.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatments_df['dosage_end']=treatments_df['dosage_range'].str.split('-').str.get(1)

# %%
treatments_df.drop(columns='dosage_range',inplace=True)
# Out:
# C:\Users\pande\AppData\Local\Temp\ipykernel_14300\477564058.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatments_df.drop(columns='dosage_range',inplace=True)

# %%
treatments_df['dosage_start']=treatments_df['dosage_start'].str.replace('u','')
treatments_df['dosage_end']=treatments_df['dosage_end'].str.replace('u','')
# Out:
# C:\Users\pande\AppData\Local\Temp\ipykernel_14300\169098340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatments_df['dosage_start']=treatments_df['dosage_start'].str.replace('u','')
# C:\Users\pande\AppData\Local\Temp\ipykernel_14300\169098340.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatments_df['dosage_end']=treatments_df['dosage_end'].str.replace('u','')

# %%
treatments_df
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20           NaN  auralin
# 3           skye  gormanston         7.97       7.62          0.35  auralin
# 6         sophia      haugen         7.65       7.27          0.38  auralin
# 7          eddie      archer         7.89       7.55          0.34  auralin
# 9           asia     woźniak         7.76       7.37           NaN  auralin
# ..           ...         ...          ...        ...           ...      ...
# 688  christopher    woodward         7.51       7.06          0.95  novodra
# 690        maret    sultygov         7.67       7.30           NaN  novodra
# 694        lixue       hsueh         9.21       8.80          0.91  novodra
# 696        jakob    jakobsen         7.96       7.51          0.95  novodra
# 698        berta  napolitani         7.68       7.21           NaN  novodra
#
#     dosage_start dosage_end
# ...

# %%
treatments_df['dosage_start']=treatments_df['dosage_start'].astype('int')
treatments_df['dosage_end']=treatments_df['dosage_end'].astype('int')
# Out:
# C:\Users\pande\AppData\Local\Temp\ipykernel_14300\4238115183.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatments_df['dosage_start']=treatments_df['dosage_start'].astype('int')
# C:\Users\pande\AppData\Local\Temp\ipykernel_14300\4238115183.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatments_df['dosage_end']=treatments_df['dosage_end'].astype('int')

# %%
treatments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 698
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    350 non-null    object
#  1   surname       350 non-null    object
#  2   hba1c_start   350 non-null    float64
#  3   hba1c_end     350 non-null    float64
#  4   hba1c_change  213 non-null    float64
#  5   type          350 non-null    object
#  6   dosage_start  350 non-null    int32
#  7   dosage_end    350 non-null    int32
# dtypes: float64(3), int32(2), object(3)
# memory usage: 30.0+ KB
